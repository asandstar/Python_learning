# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv('data\High-speed rail.csv',index_col='Country')
data.plot(y='Operation',kind='bar',fontsize=12,title='Operation Mileage',rot=45)
plt.ylabel('Mileage(km)')
plt.annotate('Longest!',xy=(0,20000),xytext=(1,20000),arrowprops=dict(arrowstyle='->'))
plt.show()

data=pd.read_csv('data\High-speed rail.csv',index_col='Country')
data.plot(y=['Operation','Under-construction','Planning'],kind='barh',stacked=True)
plt.xlabel('Mileage(km)')
plt.show()

data['Operation'].plot(x='Country',y='Operation',kind='pie',figsize=(6,6),title='Operation Mileage',fontsize=14,shadow=True,startangle=120,autopct='%1.1f%%')
plt.ylabel('')
plt.show()
